# %%
nums=[2,4,6,8]
print(type(nums), nums)
nums.append(10)
print(nums)

# %%
items=[]
items.append(2)
items.append(8)
items.append("abc")
backup=items.copy()
print("items=", items)
print("backup=", backup)

# %%
items.append(12)
print(items)

# %%
help(list)

# %%
count_value=items.count(12)
print(count_value)

# %%
items.extend([5,3])
print(items)

# %%
print(items.index(5))

# %%
items.insert(2, 11)
print(items)

# %%
items.insert(1, 20)
print(items)

# %%
items.pop(2)
print(items)

# %%
items.remove(12)
print(items)

# %%
items.reverse()
print(items)

# %%
items.remove("abc")
print(items)

# %%
items.sort(reverse=True)
print(items)

# %%
items.sort(reverse=False)
print(items)

# %%
help(tuple)

# %%
data=(2,4,6,8,10)
print(data)

# %%
total=data.count(4)
print(total)

# %%
print(data[2])

# %%
print(data[-1])

# %%
value=(9)
print(data)

# %%
numbers={2,4,6,8,10,12}
print(numbers)

# %%
help(set)

# %%
other={2,4}
print(numbers-other)

# %%
numbers.add(14)
print(numbers)

# %%
numbers.clear()
print(numbers)

# %%
numbers={2,4,6,8,10}
print(numbers)

# %%
backup=numbers.copy()
print(backup)

# %%
print(numbers)

# %%
numbers.discard(6)
print(numbers)

# %%
numbers={2,4,6,8}
other={2,4}
common=numbers.intersection(other)
print(common)

# %%
separate=numbers.isdisjoint(other)
print(separate)

# %%
small={2,4}
result=small.issubset(numbers)
print(result)

# %%
result=numbers.issuperset(small)
print(result)

# %%
removed=numbers.pop()
print(removed)

# %%
print(numbers)
