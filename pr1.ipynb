# %%
print("hello world")
# Out:
# hello world

# %%
x=5
print("x")
# Out:
# x

# %%
x=5
print(type(x))
# Out:
# <class 'int'>

# %%
x=5.5
print(type(x))
# Out:
# <class 'float'>

# %%
x="twinkal"
print(type(x))
# Out:
# <class 'str'>

# %%
x=6
y=3
print((x+y))
# Out:
# 9

# %%
# ?print

# %%
x=7
y=2
print((x*y))
# Out:
# 14

# %%
x=4
y=2
print((x-y))
# Out:
# 2

# %%
x=2
y=4
print((y/x))
# Out:
# 2.0

# %%
x=2
y=4
z=x+y
print("sum of x and y:",z)
# Out:
# sum of x and y: 6

# %%
x=4
y=3
z=x*y
print("Multiplication of x and y:",z)
# Out:
# Multiplication of x and y: 12

# %%
x=5.5
print("rupees:",int(x))
# Out:
# rupees: 5

# %%
x=5.5
print("rupees:",int(x))
print("paisa:",float(x)-int(x))
# Out:
# rupees: 5
# paisa: 0.5

# %%
x=5
y=3.5
z="twinkal"
v=True
print(type(x))
print(type(y))
print(type(z))
print(type(v))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
x=6
y=3
print(type(x==y))
# Out:
# <class 'bool'>

# %%
x=6
y=4
print((x==y))
# Out:
# False

# %%
x=4
y=4
print((x==y))
# Out:
# True
