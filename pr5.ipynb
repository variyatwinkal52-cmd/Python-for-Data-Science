# %%
f = open("sample1.txt", "w")

f.write("Good Morning!\n")
f.write("Welcome to Python.")

f.close()

print("Data written successfully!!!!.")
# Out:
# Data written successfully!!!!.

# %%
f = open("sample1.txt", "r") 
data = f.read()
print(data)
f.close()
# Out:
# Good Morning!
# Welcome to Python.

# %%
f = open("sample1.txt", "a") 
f.write("\nThis line is appended.")
f.close()

# %%
data = b"Hello Binary File"

f = open("sample.bin", "wb")
f.write(data)
f.close()

print("Data written successfully!")
# Out:
# Data written successfully!

# %%
f = open("sample.bin", "rb") 
data = f.read()
print(data)
# Out:
# b'Hello Binary File'

# %%
data = b"Appended Binary Data"

f = open("sample.bin", "ab")
f.write(data)
f.close()

print("Data appended successfully!")
# Out:
# Data appended successfully!

# %%
import csv

f = open("students.csv", "w", newline="") 
writer = csv.write(f) 
write.writerow(["ID", "Name", "Marks"])
write.writerow([1, "twinkal", 90])
write.writerow([2, "yashvi", 85])
print("Data written succtwinkle essfully!")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-1ebfda6b33bf> in <module>
#       2
#       3 f = open("students.csv", "w", newline="")
# ----> 4 writer = csv.write(f)
#       5 write.writerow(["ID", "Name", "Marks"])
#       6 write.writerow([1, "twinkal", 90])
#
# AttributeError: module 'csv' has no attribute 'write'

# %%
import csv


f = open("students.csv", "w", newline="") 
writer = csv.writer(f)

    
writer.writerow(["ID", "Name", "Marks"])

    
writer.writerow([1, "Alice", 90])
writer.writerow([2, "Bob", 85])

print("Data written successfully.")
# Out:
# Data written successfully.

# %%
import csv


f = open("students.csv", "r") 
reader = csv.reader(f)

for row in reader:
    print(row)
# Out:
# ['3', 'Charlie', '88']
# ['3', 'rensi', '88']

# %%
import csv


with open("students.csv", "a", newline="") as file:
    writer = csv.writer(file)

    writer.writerow([3, "rensi", 88])

print("Data appended successfully.")
# Out:
# Data appended successfully.
